# %%
a = int(input("Enter your 1st number:"))
b = int(input("Enter your 2nd number:"))

print("Your addition of two numbers is ",a+b)
# Out:
# enter your 1st number: 4
# enter your 2nd number: 14
# your addition of two numbers is  18
